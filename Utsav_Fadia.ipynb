# %%
conda install -c conda-forge altair vega_datasets
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
#
# Note: you may need to restart the kernel to use updated packages.## Package Plan ##
#
#   environment location: C:\Users\utyyy\anaconda3
#
#   added / updated specs:
#     - altair
#     - vega_datasets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.2.0               |     pyhd8ed1ab_1         711 KB  conda-forge
#     conda-4.12.0               |   py39hcbf5309_0         1.0 MB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     vega_datasets-0.9.0        |     pyhd3deb0d_0         179 KB  conda-forge
#
#     ------------------------------------------------------------
#                                            Total:         1.9 MB
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.2.0-pyhd8ed1ab_1
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39
#   vega_datasets      conda-forge/noarch::vega_datasets-0.9.0-pyhd3deb0d_0
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-4.10.3-py39haa95532_0 --> conda-forge::conda-4.12.0-py39hcbf5309_0
#
#
#
# Downloading and Extracting Packages
#
# conda-4.12.0         | 1.0 MB    |            |   0%
# conda-4.12.0         | 1.0 MB    | 1          |   2%
# conda-4.12.0         | 1.0 MB    | ########## | 100%
# conda-4.12.0         | 1.0 MB    | ########## | 100%
#
# altair-4.2.0         | 711 KB    |            |   0%
# altair-4.2.0         | 711 KB    | #8         |  18%
# altair-4.2.0         | 711 KB    | ########## | 100%
# altair-4.2.0         | 711 KB    | ########## | 100%
#
# vega_datasets-0.9.0  | 179 KB    |            |   0%
# vega_datasets-0.9.0  | 179 KB    | ########## | 100%
# vega_datasets-0.9.0  | 179 KB    | ########## | 100%
#
# python_abi-3.9       | 4 KB      |            |   0%
# python_abi-3.9       | 4 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import pandas as pd
import numpy as np
import altair as alt
from vega_datasets import data

# %%
df = pd.read_csv(r"C:\Users\utyyy\OneDrive - The University of Texas at Dallas\Desktop\UTD\Utsav UTD SEM 2\Data Viz\Assignments\Assingnment 12\JHU.csv")

# %%
df.head()
# Out:
#    OBJECTID Countyname  ST_Name ST_Abbr  ST_ID  FIPS  FatalityRa  Confirmedb  \
# 0         1    Autauga  Alabama      AL      1  1001    2.097902     1285.95
# 1         2    Baldwin  Alabama      AL      1  1003    0.820283      615.08
# 2         3    Barbour  Alabama      AL      1  1005    0.497512     1615.69
# 3         4       Bibb  Alabama      AL      1  1007    0.440529     1013.39
# 4         5     Blount  Alabama      AL      1  1009    0.302115      572.27
#
#    DeathsbyPo  PCTPOVALL_  ...  Day_7  Day_8  Day_9 Day_10 Day_11 Day_12  \
# 0   26.977932        13.8  ...   26.0    3.0   24.0   23.0    7.0    8.0
# 1    5.045362         9.8  ...   86.0   30.0   18.0   18.0   93.0   49.0
# 2    8.038262        30.9  ...    4.0    4.0    2.0    2.0   12.0   10.0
# 3    4.464286        21.8  ...    2.0    4.0    3.0    1.0   10.0    5.0
# 4    1.728907        13.2  ...    8.0    8.0    5.0    4.0    8.0    4.0
#
#   Day_13 Day_14   Shape__Area  Shape__Length
# 0   15.0    9.0  2.209382e+09  246839.865479
# 1   23.0   37.0  5.770469e+09  728445.072448
# 2    1.0    3.0  3.258643e+09  307285.154510
# 3    4.0    5.0  2.310715e+09  227886.963840
# 4   10.0    8.0  2.456058e+09  286306.840721
#
# [5 rows x 84 columns]

# %%
df = df[['Countyname', 'ST_Name', 'ST_Abbr', 'ST_ID', 'FIPS', 'FatalityRa', 'Confirmed', 'Deaths', 'TotalPop']]
df = df.head(3250)
df
# Out:
#       Countyname        ST_Name ST_Abbr  ST_ID   FIPS  FatalityRa  Confirmed  \
# 0        Autauga        Alabama      AL      1   1001    2.097902        715
# 1        Baldwin        Alabama      AL      1   1003    0.820283       1341
# 2        Barbour        Alabama      AL      1   1005    0.497512        402
# 3           Bibb        Alabama      AL      1   1007    0.440529        227
# 4         Blount        Alabama      AL      1   1009    0.302115        331
# ...          ...            ...     ...    ...    ...         ...        ...
# 3245  Unassigned       Virginia              0  90051    0.000000          0
# 3246  Unassigned     Washington              0  90053    0.729927        137
# 3247  Unassigned  West Virginia              0  90054    0.000000          0
# 3248  Unassigned      Wisconsin              0  90055    0.000000          0
# 3249  Unassigned        Wyoming              0  90056    0.000000          0
#
#       Deaths  TotalPop
# 0         15     55200
# 1         11    208107
# 2          2     25782
# 3          1     22527
# 4          1     57645
# ...      ...       ...
# 3245       0         0
# 3246       1         0
# 3247       0         0
# 3248       0         0
# 3249       0         0
#
# [3250 rows x 9 columns]

# %%
alt.Chart(df).transform_aggregate(
    count = 'sum(Confirmed):Q',
    groupby=['ST_Name']
).transform_window(
    rank='rank(count)',
    sort=[alt.SortField('count',order='descending')]
).transform_filter(
    alt.datum.rank < 11
).mark_bar().encode(
    y = alt.Y('ST_Name:N', sort = '-x'),
    x='count:Q'
)
# Out:
# alt.Chart(...)

# %%
input_dropdown = alt.binding_select(options = ['New York','California','Florida','Texas','New Jersey'])
selection = alt.selection_single(fields=['ST_Name'], bind=input_dropdown, name='State')
color = alt.condition(selection,
                     alt.Color('ST_Name:N', legend=None),
                     alt.value('lightgray'))

alt.Chart(df).mark_point().encode(
    x=alt.X('Confirmed:Q', scale= alt.Scale(domain=[0,50000])),
    y=alt.Y('Deaths:Q', scale=alt.Scale(domain=[0,4000])),
    color=color,
    tooltip= ['Countyname:N','ST_Name']
).add_selection(
    selection
).properties(
    width=800,
    height=500
).interactive()
# Out:
# alt.Chart(...)

# %%
counties = alt.topo_feature(data.us_10m.url, 'counties')

alt.Chart(counties).mark_geoshape().encode(
color=alt.Color('FatalityRa:Q',scale=alt.Scale(domain=[1,10], scheme='bluepurple')),
tooltip=['FatalityRa:Q']
).transform_lookup(
lookup='id',
from_=alt.LookupData(df, 'FIPS',['FatalityRa'])
).project(
type='albersUsa'
).properties(
width=500,
height=300
)
# Out:
# alt.Chart(...)
